# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install twscrape
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.5 MB/s eta 0:00:00
# ...

# %%
import asyncio
from twscrape import API, gather
from twscrape.logger import set_log_level

# %%
async def main():
    api = API("twitter_accounts")  # or API("path-to.db") - default is `accounts.db`

    # ADD ACCOUNTS (for CLI usage see BELOW)
    await api.pool.add_account("user1", "pass1", "u1@example.com", "mail_pass1")
    await api.pool.add_account("user2", "pass2", "u2@example.com", "mail_pass2")
    await api.pool.login_all()

    # or add account with COOKIES (with cookies login not required)
    cookies = "abc=12; ct0=xyz"  # or '{"abc": "12", "ct0": "xyz"}'
    await api.pool.add_account("user3", "pass3", "u3@mail.com", "mail_pass3", cookies=cookies)

    # add account with PROXY
    proxy = "http://login:pass@example.com:8080"
    await api.pool.add_account("user4", "pass4", "u4@mail.com", "mail_pass4", proxy=proxy)

    # API USAGE

    # search (latest tab)
    await gather(api.search("elon musk", limit=20))  # list[Tweet]
    # change search tab (product), can be: Top, Latest (default), Media
    await gather(api.search("elon musk", limit=20, kv={"product": "Top"}))

    # tweet info
    tweet_id = 20
    await api.tweet_details(tweet_id)  # Tweet
    await gather(api.retweeters(tweet_id, limit=20))  # list[User]
    await gather(api.favoriters(tweet_id, limit=20))  # list[User]

    # get user by login
    user_login = "xdevelopers"
    await api.user_by_login(user_login)  # User

    # user info
    user_id = 2244994945
    await api.user_by_id(user_id)  # User
    await gather(api.followers(user_id, limit=20))  # list[User]
    await gather(api.following(user_id, limit=20))  # list[User]
    await gather(api.user_tweets(user_id, limit=20))  # list[Tweet]
    await gather(api.user_tweets_and_replies(user_id, limit=20))  # list[Tweet]

    # list info
    list_id = 123456789
    await gather(api.list_timeline(list_id))

    # NOTE 1: gather is a helper function to receive all data as list, FOR can be used as well:
    async for tweet in api.search("elon musk"):
        print(tweet.id, tweet.user.username, tweet.rawContent)  # tweet is `Tweet` object

    # NOTE 2: all methods have `raw` version (returns `httpx.Response` object):
    async for rep in api.search_raw("elon musk"):
        print(rep.status_code, rep.json())  # rep is `httpx.Response` object

    # change log level, default info
    set_log_level("DEBUG")

    # Tweet & User model can be converted to regular dict or json, e.g.:
    doc = await api.user_by_id(user_id)  # User
    doc.dict()  # -> python dict
    doc.json()  # -> json string

# %%
from contextlib import aclosing

async with aclosing(api.search("elon musk")) as gen:
    async for tweet in gen:
        if tweet.id < 200:
            break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-430dd9a10013> in <cell line: 3>()
#       1 from contextlib import aclosing
#       2
# ----> 3 async with aclosing(api.search("elon musk")) as gen:
#       4     async for tweet in gen:
#       5         if tweet.id < 200:
#
# NameError: name 'api' is not defined

# %%
from re import search
async def main():
    api = API()

    await api.pool.add_account("analysis_s1", "SENTanalysis1*", "sentanalysis241@gmail.com", "SENTanalysis1*")
    await api.pool.add_account("Analysis_Sent2", "SENTanalysis2*", "sentanalysis2@gmail.com", "SENTanalysis02*")
    await api.pool.login_all()

    q = 'Jokic since:2023-12-01 until:2023-12-02'
    async for tweet in api.search(q, limit=10):
        print(tweet.id)
        print(tweet.user.username)
        print(tweet.rawContent)
        print(tweet.date)

# %%
from re import search
tweet_dict= {"Tweet ID":[], "Username":[], "Content":[], "Date":[]}
async def main():
    api = API()


    await api.pool.add_account("analysis_s1", "SENTanalysis1*", "sentanalysis241@gmail.com", "SENTanalysis1*")
    await api.pool.add_account("Analysis_Sent2", "SENTanalysis2*", "sentanalysis2@gmail.com", "SENTanalysis02*")
    await api.pool.login_all()

    q = 'Luka_Doncic since:2023-11-28 until:2023-11-29'
    async for tweet in api.search(q, limit=50):
        #print(tweet.id)
        tweet_dict["Tweet ID"].append(tweet.id)
        #print(tweet.user.username)
        tweet_dict["Username"].append(tweet.user.username)
        #print(tweet.rawContent)
        tweet_dict["Content"].append(tweet.rawContent)
        #print(tweet.date)
        tweet_dict["Date"].append(tweet.date)

# %%
asyncio.run(await main())
# Out:
# 2023-12-02 22:38:52.695 | WARNING  | twscrape.accounts_pool:add_account:76 - Account analysis_s1 already exists
# 2023-12-02 22:38:52.704 | WARNING  | twscrape.accounts_pool:add_account:76 - Account Analysis_Sent2 already exists
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-122-04849ca13588> in <cell line: 1>()
# ----> 1 asyncio.run(await main())
#
# /usr/lib/python3.10/asyncio/runners.py in run(main, debug)
#      31     """
#      32     if events._get_running_loop() is not None:
# ---> 33         raise RuntimeError(
#      34             "asyncio.run() cannot be called from a running event loop")
#      35
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
print(tweet_dict)
# Out:
# {'Tweet ID': [1728201417792634918, 1728201347710005349, 1724185722612023329, 1728201214360481850, 1728200796628729982, 1728200664768254401, 1728127040526970973, 1728200603762081954, 1728200022951604238, 1728199206937239785, 1724100756318327203, 1728199120169611383, 1728199139807346857, 1728198437580296464, 1728198257627848760, 1728198109438566651, 1728197941482111366, 1727989259817107809, 1728197917687837046, 1728197809097322829, 1728197670563696846, 1728197637491601563, 1728194883725254744, 1728197583175364819, 1728156770021859672, 1724185722612023329, 1728197558798012927, 1728093695558266885, 1728197305877336405, 1728197163912683593, 1728186195866485168, 1728197076436271563, 1728197019850944627, 1728197012401918342, 1724100783304478944, 1728196981506638276, 1728196950196191633, 1728196769039683656, 1728196687691170089, 1728196400394150388, 1728196343145926725, 1727989257246032237, 1728196180432109660, 1728195364287631407, 1728196176137380219, 1728196151852052717, 172819602517574454
# ...

# %%
print(len(tweet_dict["Content"]))
# Out:
# 61

# %%
Jokik_df = pd.DataFrame.from_dict(tweet_dict)

# %%
print(Jokik_df["Content"].head(5))
# Out:
# 0    @Bobbypbuckets some said if u put ur ears near...
# 1           @DAVEYSUICIDE If jokic is playing, go dude
# 2    @Lakersallthewa3 Last season was disgraceful w...
# 3    @cmattdowns Nurkic going over. He’s gonna kill...
# 4    @sixringsofsteeI Jokic doesn’t seem to be in t...
# Name: Content, dtype: object

# %%
Embiid_df = pd.DataFrame.from_dict(tweet_dict)

# %%
print(Embiid_df["Content"].head(5))
# Out:
# 0                  @BadTradeM8 @NBAMemes respct Embiid
# 1    @LamarHeisman @YoNipplesSoft a tight end compa...
# 2    This quiz will explore the diverse world we li...
# 3    @DwnBadBearsFan @JoeyC___ @AyooTexanNation @Bl...
# 4    @DeanScorpion_ “Embiid down the lane, takes th...
# Name: Content, dtype: object

# %%
Shai_Gilgeous_df = pd.DataFrame.from_dict(tweet_dict)

# %%
print(len(Shai_Gilgeous_df["Content"]))
# Out:
# 62

# %%
Tyrese_Haliburton_df = pd.DataFrame.from_dict(tweet_dict)

# %%
print(Tyrese_Haliburton_df["Content"])
# Out:
# 0     🟡 — Tyrese Haliburton: Double-Double.\n\nI’m b...
# 1     𝙄𝙣𝙙𝙞𝙖𝙣𝙖 𝙋𝙖𝙘𝙚𝙧𝙨 @ 𝙈𝙞𝙖𝙢𝙞 𝙃𝙚𝙖𝙩\n\n🔴 — Bam Adebayo...
# 2                       Support Elon Musk. Buy my book.
# 3     HERO AI ranks these 5 picks as the best plays ...
# 4     Tyrese Haliburton has been HOOPIN' hoopin this...
#                             ...
# 63    NBA 11/30 Plays🏀\n\nBuddy Hield “U” 4.5 reboun...
# 64    Freight rail safety is our commitment. Ongoing...
# 65    I didn’t know Tyrese Haliburton was playing th...
# 66             @jackeroniAZ you https://t.co/PyDEeCmT7a
# 67    @YettFr @highrollerhoops @BodiedByBron I saw o...
# Name: Content, Length: 68, dtype: object

# %%
Luka_Doncic_df = pd.DataFrame.from_dict(tweet_dict)

# %%
print(Luka_Doncic_df["Content"])
# Out:
# 0     FanDuel - NBA Super Boost +100\nShai Gilgeous-...
# 1     Hoje tem Dallas Mavericks Hoje tem Luka Doncic...
# 2     A Leila do Dallas Mavericks https://t.co/bUXa8...
# 3     @pisounalinha Ou seja, o jogador Luka Doncic, ...
# 4                               https://t.co/q3Z0QsU31z
# 5     Sources: Mark Cuban is selling a majority stak...
# 6                      LUKA DONCIC VOCE VAI SER CAMPEAO
# 7     @Mavs_FFL This is why he’s on his final two se...
# 8     @timeforjeffrey This is sad.  This is the begi...
# 9     @bronisabeast @CookedbyGurru I can’t juice thi...
# 10    Luka Dončić (thumb sprain) and Dereck Lively I...
# 11    @easportsdfw @lynziekate That’s the article th...
# 12    2018-19 Panini Threads NBA Luka Doncic Rookie ...
# 13    Naw fr it don’t show the real you until you me...
# 14    You could be whoever you want on this internet...
# 15    i just found out luka dončić was born the same...
# 16                      @UnderdogFantasy Luka Doncic 47
# ...
